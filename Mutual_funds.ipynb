# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../Datasets/mutual_funds_india.csv")

# %%
df
# Out:
#       Unnamed: 0  AMC_name                                   Mutual Fund Name  \
# 0              0     Quant            Quant Small Cap Fund Direct Plan Growth
# 1              1    Canara         Canara Robeco Small Cap Fund Direct Growth
# 2              2      PGIM  PGIM India Midcap Opportunities Fund Direct Gr...
# 3              3      Bank         Bank of India Small Cap Fund Direct Growth
# 4              4     Quant                       Quant Tax Plan Direct Growth
# ...          ...       ...                                                ...
# 1083        1083  Sundaram       Sundaram Ultra Short Term Fund Direct Growth
# 1084        1084       BNP           BNP Paribas Overnight Fund Direct Growth
# 1085        1085   Invesco         Invesco India Overnight Fund Direct Growth
# 1086        1086      HSBC       HSBC Ultra Short Duration Fund Direct Growth
# 1087        1087       ITI                   ITI Overnight Fund Direct Growth
#
# ...

# %%
df=df.drop("Unnamed: 0",axis=1)

# %%
df
# Out:
#       AMC_name                                   Mutual Fund Name category  \
# 0        Quant            Quant Small Cap Fund Direct Plan Growth   Equity
# 1       Canara         Canara Robeco Small Cap Fund Direct Growth   Equity
# 2         PGIM  PGIM India Midcap Opportunities Fund Direct Gr...   Equity
# 3         Bank         Bank of India Small Cap Fund Direct Growth   Equity
# 4        Quant                       Quant Tax Plan Direct Growth   Equity
# ...        ...                                                ...      ...
# 1083  Sundaram       Sundaram Ultra Short Term Fund Direct Growth     Debt
# 1084       BNP           BNP Paribas Overnight Fund Direct Growth     Debt
# 1085   Invesco         Invesco India Overnight Fund Direct Growth     Debt
# 1086      HSBC       HSBC Ultra Short Duration Fund Direct Growth     Debt
# 1087       ITI                   ITI Overnight Fund Direct Growth     Debt
#
# ...

# %%
df.dtypes
# Out:
# AMC_name             object
# Mutual Fund Name     object
# category             object
# risk_type            object
# fund_rating         float64
# return_1yr          float64
# return_3yr          float64
# return_5yr          float64
# dtype: object

# %%
df.return_3yr = df.return_3yr.fillna(0)

# %%
df.fillna(0)
# Out:
#       AMC_name                                   Mutual Fund Name category  \
# 0        Quant            Quant Small Cap Fund Direct Plan Growth   Equity
# 1       Canara         Canara Robeco Small Cap Fund Direct Growth   Equity
# 2         PGIM  PGIM India Midcap Opportunities Fund Direct Gr...   Equity
# 3         Bank         Bank of India Small Cap Fund Direct Growth   Equity
# 4        Quant                       Quant Tax Plan Direct Growth   Equity
# ...        ...                                                ...      ...
# 1083  Sundaram       Sundaram Ultra Short Term Fund Direct Growth     Debt
# 1084       BNP           BNP Paribas Overnight Fund Direct Growth     Debt
# 1085   Invesco         Invesco India Overnight Fund Direct Growth     Debt
# 1086      HSBC       HSBC Ultra Short Duration Fund Direct Growth     Debt
# 1087       ITI                   ITI Overnight Fund Direct Growth     Debt
#
# ...

# %%
df=df.rename(columns={'Mutual Fund Name':'Mutual_Fund_Name'})

# %%
df
# Out:
#       AMC_name                                   Mutual_Fund_Name category  \
# 0        Quant            Quant Small Cap Fund Direct Plan Growth   Equity
# 1       Canara         Canara Robeco Small Cap Fund Direct Growth   Equity
# 2         PGIM  PGIM India Midcap Opportunities Fund Direct Gr...   Equity
# 3         Bank         Bank of India Small Cap Fund Direct Growth   Equity
# 4        Quant                       Quant Tax Plan Direct Growth   Equity
# ...        ...                                                ...      ...
# 1083  Sundaram       Sundaram Ultra Short Term Fund Direct Growth     Debt
# 1084       BNP           BNP Paribas Overnight Fund Direct Growth     Debt
# 1085   Invesco         Invesco India Overnight Fund Direct Growth     Debt
# 1086      HSBC       HSBC Ultra Short Duration Fund Direct Growth     Debt
# 1087       ITI                   ITI Overnight Fund Direct Growth     Debt
#
# ...

# %%
df.AMC_name.unique()
# Out:
# array(['Quant', 'Canara', 'PGIM', 'Bank', 'Kotak', 'Nippon', 'Edelweiss',
#        'Union', 'Tata', 'SBI', 'DSP', 'ICICI', 'IDBI', 'Invesco', 'Axis',
#        'Mirae', 'Sundaram', 'L&T', 'Motilal', 'UTI', 'Mahindra', 'Aditya',
#        'Baroda', 'IDFC', 'HDFC', 'HSBC', 'Franklin', 'Parag', 'Templeton',
#        'Taurus', 'Principal', 'IIFL', 'LIC', 'JM', 'Navi', 'Quantum',
#        'BNP', 'Indiabulls', 'Shriram', 'ITI', 'Reliance', 'BOI',
#        'WhiteOak', 'BHARAT', 'TRUSTMF', 'Samco', 'NJ'], dtype=object)

# %%
df.Mutual_Fund_Name.unique()
# Out:
# array(['Quant Small Cap Fund Direct Plan Growth',
#        'Canara Robeco Small Cap Fund Direct Growth',
#        'PGIM India Midcap Opportunities Fund Direct Growth', ...,
#        'Invesco India Overnight Fund Direct Growth',
#        'HSBC Ultra Short Duration Fund Direct Growth',
#        'ITI Overnight Fund Direct Growth'], shape=(1068,), dtype=object)

# %%
df.	category.unique()
# Out:
# array(['Equity', 'Hybrid', 'Other', 'Solution Oriented', 'Debt'],
#       dtype=object)

# %%
df.risk_type.unique()
# Out:
# array(['Very High Risk', 'Moderately High Risk', 'High Risk',
#        'Moderate Risk', 'Low to Moderate Risk', 'Moderately Low Risk',
#        'Low Risk'], dtype=object)

# %%
df.describe()
# Out:
#        fund_rating  return_1yr   return_3yr  return_5yr
# count   741.000000  975.000000  1088.000000  696.000000
# mean      3.066127    4.208585    10.334825    9.541135
# std       1.102675    8.208132     9.763274    4.366601
# min       1.000000  -39.000000    -9.240000   -2.950000
# 25%       2.000000    2.155000     2.700000    6.300000
# 50%       3.000000    3.750000     6.645000    8.650000
# 75%       4.000000    5.640000    18.042500   12.790000
# max       5.000000   78.290000    54.370000   28.910000

# %%
df.AMC_name.value_counts()
# Out:
# AMC_name
# ICICI         78
# Aditya        63
# Nippon        54
# SBI           50
# UTI           48
# HDFC          47
# Axis          45
# Kotak         42
# DSP           42
# IDFC          41
# Tata          41
# Invesco       34
# Baroda        33
# Sundaram      32
# Edelweiss     31
# Franklin      30
# L&T           29
# Mirae         28
# HSBC          25
# Motilal       23
# PGIM          22
# IDBI          21
# Canara        21
# LIC           19
# Mahindra      19
# Union         17
# ITI           17
# Navi          17
# Quant         16
# JM            15
# Bank          14
# Taurus        11
# Quantum        9
# Indiabulls     9
# Principal      8
# Shriram        6
# BHARAT         5
# TRUSTMF        5
# Parag          4
# IIFL           4
# WhiteOak       4
# BNP            3
# Templeton      2
# Reliance       1
# BOI            1
# Samco          1
# NJ             1
# Name: count, dtype: int64

# %%
df.Mutual_Fund_Name.value_counts()
# Out:
# Mutual_Fund_Name
# Invesco India Flexi Cap Fund Direct Growth                           2
# Invesco India Invesco EQQQ NASDAQ 100 ETF FoF Direct Growth          2
# Union Midcap Fund Direct Growth                                      2
# Aditya Birla Sun Life Nifty SDL Apr 2027 Index Fund Direct Growth    2
# IDFC CRISIL Gilt 2028 Index Fund Direct Growth                       2
#                                                                     ..
# Aditya Birla Sun Life Equity Hybrid '95 Fund Direct Growth           1
# HSBC Managed Solutions India Moderate Fund Direct Growth             1
# Nippon India Retirement Fund Wealth Creation Scheme Direct Growth    1
# Invesco India Financial Services Fund Direct Growth                  1
# ITI Overnight Fund Direct Growth                                     1
# Name: count, Length: 1068, dtype: int64

# %%
df.category.value_counts()
# Out:
# category
# Equity               380
# Debt                 332
# Other                214
# Hybrid               137
# Solution Oriented     25
# Name: count, dtype: int64

# %%
df.risk_type.value_counts()
# Out:
# risk_type
# Very High Risk          571
# Moderate Risk           157
# Low to Moderate Risk    155
# Moderately High Risk     94
# Low Risk                 61
# High Risk                42
# Moderately Low Risk       8
# Name: count, dtype: int64

# %%
sb.pairplot(df)
plt.show()

# %%
a=df.groupby ('category') ['return_3yr'].mean()

# %%
a
# Out:
# category
# Debt                  4.649247
# Equity               18.024132
# Hybrid               10.570584
# Other                 5.473738
# Solution Oriented     9.280800
# Name: return_3yr, dtype: float64

# %%
b=df.groupby ('category') ['return_1yr'].mean()

# %%
b
# Out:
# category
# Debt                 3.816006
# Equity               6.097003
# Hybrid               4.690227
# Other               -0.135245
# Solution Oriented    4.539200
# Name: return_1yr, dtype: float64

# %%
c=df.groupby ('category') ['return_5yr'].mean()

# %%
c
# Out:
# category
# Debt                  5.954174
# Equity               13.167366
# Hybrid                8.818763
# Other                 9.430000
# Solution Oriented     9.302727
# Name: return_5yr, dtype: float64

# %%
fig = plt.figure(figsize=[20,10])
fig.add_subplot(221)
sb.barplot(a)

fig.add_subplot(222)
sb.barplot(b)

fig.add_subplot(223)
sb.barplot(c)

plt.show()

# %%
d=df.groupby ('risk_type') ['return_5yr'].mean()

# %%
d
# Out:
# risk_type
# High Risk                9.303214
# Low Risk                 5.195000
# Low to Moderate Risk     5.948190
# Moderate Risk            6.132857
# Moderately High Risk     7.680962
# Moderately Low Risk      6.565000
# Very High Risk          12.418796
# Name: return_5yr, dtype: float64

# %%
e=df.groupby('AMC_name') ['return_3yr'].mean()

# %%
e
# Out:
# AMC_name
# Aditya         9.836190
# Axis           6.824667
# BHARAT         0.000000
# BNP            8.903333
# BOI            4.770000
# Bank          14.340714
# Baroda        10.212727
# Canara        12.827619
# DSP           11.373810
# Edelweiss      9.556774
# Franklin      13.141333
# HDFC          10.621277
# HSBC           8.867600
# ICICI         11.058718
# IDBI          15.014762
# IDFC           8.330244
# IIFL           8.770000
# ITI            1.015882
# Indiabulls     9.582222
# Invesco        9.847059
# JM             9.942667
# Kotak         10.143095
# L&T           11.105517
# LIC           10.591053
# Mahindra       9.166316
# Mirae          8.155000
# Motilal        6.072609
# NJ             0.000000
# Navi           6.518235
# Nippon         9.869630
# PGIM           8.864091
# Parag         13.762500
# Principal      8.242500
# Quant         24.542500
# Quantum       10.778889
# Reliance      10.270000
# SBI           11.807000
# Samco          0.000000
# ...

# %%
f=df.groupby('Mutual_Fund_Name') ['return_5yr'].mean().nlargest(10)

# %%
f
# Out:
# Mutual_Fund_Name
# Tata Digital India Fund Direct Growth                     28.91
# ICICI Prudential Technology Direct Plan Growth            28.00
# Aditya Birla Sun Life Digital India Fund Direct Growth    27.02
# SBI Technology Opportunities Fund Direct Growth           25.85
# Quant Infrastructure Fund Direct Growth                   23.91
# Quant Tax Plan Direct Growth                              23.76
# Quant Active Fund Direct Growth                           23.40
# Quant Small Cap Fund Direct Plan Growth                   22.73
# Quant Mid Cap Fund Direct Growth                          22.03
# PGIM India Midcap Opportunities Fund Direct Growth        21.49
# Name: return_5yr, dtype: float64

# %%
g=pd.pivot_table(df,index='category',columns='risk_type',values='return_3yr',aggfunc='mean',margins=True)

# %%
g
# Out:
# risk_type          High Risk  Low Risk  Low to Moderate Risk  Moderate Risk  \
# category
# Debt                6.390000  2.923590              4.597483       5.209675
# Equity             18.468571       NaN                   NaN            NaN
# Hybrid              8.741429  4.230455              9.206667       7.796000
# Other               8.820833       NaN              0.000000       1.966957
# Solution Oriented  13.450000       NaN                   NaN       4.510000
# All                10.352143  3.394918              4.538387       4.894904
#
# risk_type          Moderately High Risk  Moderately Low Risk  Very High Risk  \
# category
# Debt                           6.306154               2.4300       -2.820000
# Equity                        10.497143                  NaN       18.308997
# Hybrid                         9.796316               0.0000       14.837636
# Other                          8.690000                  NaN        5.378993
# ...

# %%
h=pd.pivot_table(df,index='AMC_name',columns='category',values='Mutual_Fund_Name',aggfunc='count',margins=True)

# %%
h
# Out:
# category     Debt  Equity  Hybrid  Other  Solution Oriented   All
# AMC_name
# Aditya       13.0    23.0     5.0   18.0                4.0    63
# Axis         13.0    12.0     6.0   11.0                3.0    45
# BHARAT        NaN     NaN     NaN    5.0                NaN     5
# BNP           2.0     1.0     NaN    NaN                NaN     3
# BOI           1.0     NaN     NaN    NaN                NaN     1
# Bank          4.0     6.0     4.0    NaN                NaN    14
# Baroda       13.0    12.0     7.0    1.0                NaN    33
# Canara       10.0     9.0     2.0    NaN                NaN    21
# DSP          14.0    12.0     5.0   11.0                NaN    42
# Edelweiss     6.0     8.0     4.0   13.0                NaN    31
# Franklin      6.0    11.0     3.0   10.0                NaN    30
# HDFC         15.0    13.0     6.0   10.0                3.0    47
# HSBC          7.0     9.0     2.0    7.0                NaN    25
# ...

# %%
i=pd.pivot_table(df,index='AMC_name',columns='risk_type',values='return_5yr',aggfunc='mean',margins=True)

# %%
i
# Out:
# risk_type   High Risk  Low Risk  Low to Moderate Risk  Moderate Risk  \
# AMC_name
# Aditya       9.700000     5.510              7.030000       6.411000
# Axis        10.640000     5.630              6.685000       7.147500
# BNP               NaN       NaN                   NaN       7.320000
# BOI               NaN       NaN              5.970000            NaN
# Bank              NaN       NaN              5.550000       2.540000
# Baroda            NaN     5.530              2.740000       5.208333
# Canara            NaN       NaN              5.838000       6.632500
# DSP               NaN       NaN              6.483333       5.333333
# Edelweiss    9.450000     5.730              5.056667       7.955000
# Franklin     8.870000       NaN              6.220000       5.575000
# HDFC        10.225000     4.865              6.150000       6.235000
# HSBC         9.160000       NaN              4.306667       5.476667
# ...

# %%
j=pd.pivot_table(df,index='Mutual_Fund_Name',columns='category',values='fund_rating',aggfunc='mean',margins=True)

# %%
j
# Out:
# category                                                Debt    Equity  \
# Mutual_Fund_Name
# Aditya Birla Sun Life Active Debt Multi Manager...       NaN       NaN
# Aditya Birla Sun Life Arbitrage Fund Direct Growth       NaN       NaN
# Aditya Birla Sun Life Asset Allocator FoF Direc...       NaN       NaN
# Aditya Birla Sun Life Balanced Advantage Fund D...       NaN       NaN
# Aditya Birla Sun Life Banking & Financial Servi...       NaN  3.000000
# ...                                                      ...       ...
# Union Small Cap Fund Direct Growth                       NaN  3.000000
# WhiteOak Capital Liquid Fund Direct Growth          1.000000       NaN
# WhiteOak Capital Overnight Fund Direct Growth       1.000000       NaN
# WhiteOak Capital Ultra Short Term Fund Direct G...  2.000000       NaN
# All                                                 3.010381  3.158537
#
# category                                              Hybrid    Other  \
# Mutual_Fund_Name
# ...

# %%
print (df.category.unique())
r=input("Enter Category):")
reg=df[df.category==r]
reg
# Out:
# ['Equity' 'Hybrid' 'Other' 'Solution Oriented' 'Debt']
# Enter Category): Hybrid
#      AMC_name                                   Mutual_Fund_Name category  \
# 16      Quant                  Quant Absolute Fund Direct Growth   Hybrid
# 25      Quant               Quant Multi Asset Fund Direct Growth   Hybrid
# 50       Bank  Bank of India Mid & Small Cap Equity & Debt Fu...   Hybrid
# 134     ICICI  ICICI Prudential Equity & Debt Fund Direct Growth   Hybrid
# 151        JM                JM Equity Hybrid Fund Direct Growth   Hybrid
# ...       ...                                                ...      ...
# 1060     PGIM   PGIM India Balanced Advantage Fund Direct Growth   Hybrid
# 1077      ITI          ITI Balanced Advantage Fund Direct Growth   Hybrid
# 1079      ITI                   ITI Arbitrage Fund Direct Growth   Hybrid
# 1080      ITI                   ITI Arbitrage Fund Direct Growth   Hybrid
# 1082      ITI          ITI Balanced Advantage Fund Direct Growth   Hybrid
#
# ...

# %%
print (df.risk_type.unique())
q=input("Enter Risk Type):")
pcd=df[df.risk_type==q]
pcd
# Out:
# ['Very High Risk' 'Moderately High Risk' 'High Risk' 'Moderate Risk'
#  'Low to Moderate Risk' 'Moderately Low Risk' 'Low Risk']
# Enter Risk Type): Moderately High Risk
#       AMC_name                                   Mutual_Fund_Name  \
# 24       Mirae              Mirae Asset Midcap Fund Direct Growth
# 84       Parag          Parag Parikh Tax Saver Fund Direct Growth
# 148      ICICI  ICICI Prudential Retirement Fund Pure Equity P...
# 149      Union                   Union Focused Fund Direct Growth
# 159   Mahindra  Mahindra Manulife Hybrid Equity Nivesh Yojana ...
# ...        ...                                                ...
# 1061       ITI            ITI Long Term Equity Fund Direct Growth
# 1065      Axis            Axis All Seasons Debt FoF Direct Growth
# 1070       SBI  SBI Retirement Benefit Fund Conservative Plan ...
# 1077       ITI          ITI Balanced Advantage Fund Direct Growth
# 1082       ITI          ITI Balanced Advantage Fund Direct Growth
#
# ...

# %%
print (df.AMC_name.unique())
t=input("Enter Name):")
abc=df[df.AMC_name==t]
abc
# Out:
# ['Quant' 'Canara' 'PGIM' 'Bank' 'Kotak' 'Nippon' 'Edelweiss' 'Union'
#  'Tata' 'SBI' 'DSP' 'ICICI' 'IDBI' 'Invesco' 'Axis' 'Mirae' 'Sundaram'
#  'L&T' 'Motilal' 'UTI' 'Mahindra' 'Aditya' 'Baroda' 'IDFC' 'HDFC' 'HSBC'
#  'Franklin' 'Parag' 'Templeton' 'Taurus' 'Principal' 'IIFL' 'LIC' 'JM'
#  'Navi' 'Quantum' 'BNP' 'Indiabulls' 'Shriram' 'ITI' 'Reliance' 'BOI'
#  'WhiteOak' 'BHARAT' 'TRUSTMF' 'Samco' 'NJ']
# Enter Name): ICICI
#      AMC_name                                   Mutual_Fund_Name category  \
# 17      ICICI  ICICI Prudential Smallcap Fund Direct Plan Growth   Equity
# 33      ICICI     ICICI Prudential Technology Direct Plan Growth   Equity
# 46      ICICI  ICICI Prudential India Opportunities Fund Dire...   Equity
# 64      ICICI  ICICI Prudential Pharma Healthcare And Diagnos...   Equity
# 69      ICICI            ICICI Prudential MNC Fund Direct Growth   Equity
# ...       ...                                                ...      ...
# ...

# %%
df_mean = df.groupby('Mutual_Fund_Name')[['return_1yr', 'return_3yr', 'return_5yr']].mean()
df_mean
# Out:
#                                                     return_1yr  return_3yr  \
# Mutual_Fund_Name
# Aditya Birla Sun Life Active Debt Multi Manager...        2.58        6.17
# Aditya Birla Sun Life Arbitrage Fund Direct Growth        4.08        4.65
# Aditya Birla Sun Life Asset Allocator FoF Direc...        2.38       16.03
# Aditya Birla Sun Life Balanced Advantage Fund D...        3.55       13.94
# Aditya Birla Sun Life Banking & Financial Servi...        1.63       15.00
# ...                                                        ...         ...
# Union Small Cap Fund Direct Growth                       11.19       35.94
# WhiteOak Capital Flexi Cap Fund Direct Growth              NaN        0.00
# WhiteOak Capital Liquid Fund Direct Growth                3.60        3.71
# WhiteOak Capital Overnight Fund Direct Growth             3.67        3.55
# WhiteOak Capital Ultra Short Term Fund Direct G...        4.43        4.37
#
# ...

# %%
fig = plt.figure(figsize=[20,10])
fig.add_subplot(221)
sb.barplot(df_mean)
# Out:
# <Axes: >
